# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjana1306/Machine-Learning-Projects/blob/main/House_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
data= pd.read_csv("/content/sample_data/kc_house_data.csv")

# %%
data.head()
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
data.describe()
# Out:
#                  id         price  ...  sqft_living15     sqft_lot15
# count  2.161300e+04  2.161300e+04  ...   21613.000000   21613.000000
# mean   4.580302e+09  5.400881e+05  ...    1986.552492   12768.455652
# std    2.876566e+09  3.671272e+05  ...     685.391304   27304.179631
# min    1.000102e+06  7.500000e+04  ...     399.000000     651.000000
# 25%    2.123049e+09  3.219500e+05  ...    1490.000000    5100.000000
# 50%    3.904930e+09  4.500000e+05  ...    1840.000000    7620.000000
# 75%    7.308900e+09  6.450000e+05  ...    2360.000000   10083.000000
# max    9.900000e+09  7.700000e+06  ...    6210.000000  871200.000000
#
# [8 rows x 20 columns]

# %%
data['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of bedrooms')
plt.xlabel('bedrooms')
plt.ylabel('count')
sns.despine
# Out:
# <function seaborn.utils.despine>

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=data.lat.values,y=data.long.values,height=10)
#plt.ylabel('Longitude',fontsize=15)
#plt.xlabel('Latitude',fontsize=15)
plt.show()
#sns.despine
# Out:
# <function seaborn.utils.despine>

# %%
plt.scatter(data.price,data.sqft_living)
plt.title("Price VS Square Feet")
# Out:
# Text(0.5, 1.0, 'Price VS Square Feet')

# %%
plt.scatter(data.price,data.long)
plt.title("Price VS Location Of The Area")
# Out:
# Text(0.5, 1.0, 'Price VS Location Of The Area')

# %%
plt.scatter(data.lat,data.price)
plt.title("Price VS Latitude Of The Area")
# Out:
# Text(0.5, 1.0, 'Price VS Latitude Of The Area')

# %%
plt.scatter((data['sqft_living']+data['sqft_basement']),data['price'])

# %%
plt.scatter(data.waterfront,data.price)
plt.title('Price vs Waterfront 0=zero waterfront')
# Out:
# Text(0.5, 1.0, 'Price vs Waterfront 0=zero waterfront')

# %%
plt.scatter(data.floors,data.price)

# %%
plt.scatter(data.condition,data.price)

# %%
plt.scatter(data.zipcode,data.price)

# %%
reg=LinearRegression()

# %%
labels=data['price']
conv_dates=[1 if values == 2014 else 0 for values in data.date]
data['date']=conv_dates
train1=data.drop(['id','price'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test =train_test_split(train1 , labels ,test_size=0.10 ,random_state=2)

# %%
reg=linear_model.LinearRegression()

# %%
y_train.isnull().sum()

print(y_train.isnull().any())
#x_train.drop(['sqft_above'], axis = 1)
# Out:
# False

# %%
#print(np.isfinite(x_train).all())

print(np.isinf(y_train).all())
#x_train_inf = np.isinf(x_train)
#x_train[x_train_inf] = 0

# %%
y_train.isnull().sum()

# %%
#np.nan_to_num(x_train) 
#np.nan_to_num(y_train)

# %%
x_train = x_train.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)

# %%
reg.fit(x_train,y_train)
y_test = reg.predict(x_test)

# %%
reg.score(x_test,y_test)
